# %%
import pandas as pd

# 대규모 CSV 파일을 메모리 효율적으로 일부만 읽어서 확인
csv_file = '../data/raw/250612-DOME-dataset-raw.csv'

# 첫 5행만 읽어서 정상적으로 인식되는지 확인
df_sample = pd.read_csv(csv_file, nrows=5)
print(df_sample.head())
